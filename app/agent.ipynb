# %%
from agent import Agent
from IPython.display import Image, display
from config import API_KEY_NAME, API_KEY_PRIVATE

parsed_api_key_name = API_KEY_NAME.replace('\\n', '\n')
parsed_api_key_private = API_KEY_PRIVATE.replace('\\n', '\n')


my_agent = Agent(parsed_api_key_name, parsed_api_key_private)
display(Image(my_agent.graph.get_graph().draw_mermaid_png()))
# Out:
# Initializing agent...
# API Key Name: x-api-key
# API Key Private: x-api-key-private
